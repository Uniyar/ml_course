# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('weights_heights.csv', index_col='Index')
df.head()
# Out:
#          Height    Weight
# Index
# 1      65.78331  112.9925
# 2      71.51521  136.4873
# 3      69.39874  153.0269
# 4      68.21660  142.3354
# 5      67.78781  144.2971

# %%
df.plot.scatter(x = 'Weight', y = 'Height')
plt.xlabel("Height")
plt.ylabel("Weight")
plt.show()

# %%
data = pd.read_csv('weights_heights.csv', index_col='Index')

# %%
data.plot(x='Height', y='Weight', kind='scatter')
plt.xlabel("Weight")
plt.ylabel("Height")
x = np.linspace(0,200)
y1 = 60 + 0.05 * x
y2 = 50 + 0.16 * x
plt.plot(y1,x, y2,x)
plt.show()
